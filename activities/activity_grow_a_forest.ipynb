# %% [markdown]
# # Trees and Forests Activity
#
# In this practice, you will learn to:
#
# - Train and tune a Decision Tree.
# - Build a manual forest of trees and combine their predictions using majority voting.
# - Observe how an ensemble of models can outperform a single tree.

# %% [markdown]
# #### Part 1

# %% [markdown]
# 1. Generate data
#     - Create a moon-shaped dataset with: make_moons(n_samples=10000, noise=0.4)
#
# 2. Split the data
#     - Split the dataset into training and test sets using train_test_split().
#
# 3. Tune the model
#     - Use grid search with cross-validation, using the GridSearchCV class, to find good hyperparameters for a DecisionTreeClassifier.
#     - Hint: try different values of max_leaf_nodes.
#
# 4. Train and evaluate
#     - Train the tree on the full training set using the optimal hyperparameters.
#     - Evaluate it on the test set.
#
# You should obtain approximately 85%–87% accuracy.

# %%
# Your code here

# %% [markdown]
# #### Part 2 Grow a forest

# %% [markdown]
# 1. Generate subsets
#     - Create 1,000 subsets of the training set, each with 100 randomly selected instances.
#     - Hint: use ShuffleSplit from Scikit-Learn.
#
# 2. Train multiple trees
#     - Train a DecisionTreeClassifier on each subset, using the best hyperparameters found in Part 1.
#     - Evaluate each individual tree on the test set.
#     - Since they were trained on small datasets, they are expected to reach only about 80% accuracy.
#
# 3. Combine predictions
#     - For each instance in the test set, collect the predictions from the 1,000 trees.
#     - Keep only the most frequent prediction using mode() from SciPy.
#     - This implements majority voting.
#
# 4. Evaluate the forest
#     - Evaluate the combined predictions on the test set.
#     - You should obtain a slightly higher accuracy than that of the individual tree, about +0.5% to +1.5%.
#
# Congratulations, you have implemented your own Random Forest from scratch!

# %%
# Your code here
